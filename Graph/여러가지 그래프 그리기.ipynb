# %%
# 그래프에서 한글표현을 위해 폰트를 설치합니다.
# !apt-get update -qq
# !apt-get install fonts-nanum* -qq
# Out:
# Selecting previously unselected package fonts-nanum.
# (Reading database ... 156210 files and directories currently installed.)
# Preparing to unpack .../fonts-nanum_20170925-1_all.deb ...
# Unpacking fonts-nanum (20170925-1) ...
# Selecting previously unselected package fonts-nanum-eco.
# Preparing to unpack .../fonts-nanum-eco_1.000-6_all.deb ...
# Unpacking fonts-nanum-eco (1.000-6) ...
# Selecting previously unselected package fonts-nanum-extra.
# Preparing to unpack .../fonts-nanum-extra_20170925-1_all.deb ...
# Unpacking fonts-nanum-extra (20170925-1) ...
# Selecting previously unselected package fonts-nanum-coding.
# Preparing to unpack .../fonts-nanum-coding_2.5-1_all.deb ...
# Unpacking fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-extra (20170925-1) ...
# Setting up fonts-nanum (20170925-1) ...
# Setting up fonts-nanum-coding (2.5-1) ...
# Setting up fonts-nanum-eco (1.000-6) ...
# Processing triggers for fontconfig (2.12.6-0ubuntu2) ...

# %%
import pandas as pd
import numpy as np

import matplotlib as mpl # 그래프 옵션
import matplotlib.pyplot as plt  # 그래프 그리는 용도
import matplotlib.font_manager as fm  # 폰트 관련 용도

import seaborn as sns

# 경고 메시지 처리
import warnings

# colab 내 그래프를 바로 그리기 위한 설정
# %matplotlib inline

# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
path = '/usr/share/fonts/truetype/Noto/NotoSansKR-Black.otf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)

fm._rebuild()

# 경고메시지 출력 생략
warnings.filterwarnings('ignore')

# 런타임을 다시 실행시켜야 한글폰트가 적용됩니다
# Out:
# Noto Sans KR

# %%
df_c_rate = pd.read_csv('/content/drive/MyDrive/csv/전환율.csv', index_col = 0)
df_c_rate = df_c_rate.sort_values(by='전환율(%)', ascending = False)
df_c_rate
# Out:
#     Category      purchase      pageview     전환율(%)
# 4         뷰티   8075.666667  16896.000000  47.445172
# 2         모자  11740.608696  25316.000000  44.622435
# 11      액세서리  15410.000000  29379.000000  40.975669
# 6   선글라스/안경테  18977.500000  52129.000000  34.157172
# 5         상의  10435.437008  43685.480315  28.269610
# 9         신발   4973.155556  19516.888889  27.561672
# 0         가방   6970.255814  26489.023256  26.946369
# 3         바지  13714.950495  52326.737624  25.938244
# 7       스니커즈   6633.355769  33948.865385  22.015233
# 10       아우터   5472.841463  55573.353659  12.518224
# 12     여성 가방   2718.272727  45224.363636   9.839490
# 1     디지털/테크   1138.111111  12911.777778   6.928097
# 8         시계    320.000000   4619.000000   6.927906

# %%
sns.catplot(x='Category', y='전환율(%)', data=df_c_rate, kind='bar', aspect = 2, height = 7);
plt.title('카테고리별 전환율', size = 30);

# %%
# csv파일 불러 오는 함수 만들기

def df_read(url):
  global df_a
  df_a = pd.read_csv(url, index_col = 0)


df_read('/content/drive/MyDrive/csv/musinsa_rank_data.csv')

# %%
df_a
# Out:
#       상품고유코드   순위    브랜드명                                     상품명  Countlike  \
# 0    1778404    1      토피            2WAY 스웻 후드 집업 (MELANGE GREY)     108964
# 1    1551840    2      제로        Deep One Tuck Sweat Pants [Grey]     118414
# 2     577636    3    아디다스                    BW 아미 - 화이트 / BZ0579      63571
# 3     750908    4  후러브스아트                      유니섹스 세미 와이드 밴딩 슬랙스     154532
# 4     810034    5     컨버스                    척 70 클래식  블랙 162058C      78318
# ..       ...  ...     ...                                     ...        ...
# 985  2357810  986    뉴발란스           NBPFCS179L / MT410KF5 (WHITE)       2383
# 986  2318477  987     커버낫                 스몰 어센틱 로고 후디 집업 멜란지 그레이       2420
# 987  2407403  988  푸마 셀렉트           푸마Ⅹ아미 후드 티셔츠 - 그린 / 534069-96        637
# 988  2105470  989    소버먼트  980g pigment CUT hoody zip up-chacoal-       2967
# 989  1547899  990   아웃스탠딩  V.S.C HOOD SWEAT_MARYS_3% MELANGE GRAY      16543
#
# ...

# %%
df_b = df_a.groupby('Category').size().sort_values(ascending=False)
df_b

df_c = df_b[:-8]
df_c
# Out:
# Category
# 상의      266
# 아우터     258
# 바지      206
# 스니커즈    104
# 신발       45
# 가방       43
# 모자       27
# dtype: int64

# %%
df_c = pd.DataFrame(df_c)
df_c
# Out:
#             0
# Category
# 상의        266
# 아우터       258
# 바지        206
# 스니커즈      104
# 신발         45
# 가방         43
# 모자         27

# %%
group_names = df_c.index
group_sizes = df_c.values
group_explodes = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

fig = plt.figure(figsize = (10, 10))
plt.pie(group_sizes, labels=group_names, explode = group_explodes, autopct='%1.2f%%', startangle=90, textprops={'fontsize':14})
plt.axis('equal')
plt.legend()
plt.show()
# 중분류 추가해서 나타내보기 or 브랜드 축해서
group_names = df_e.index
group_sizes = df_e.values
group_explodes = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

fig = plt.figure(figsize = (10, 10))
plt.pie(group_sizes, labels=group_names, autopct='%1.2f%%', startangle=90, textprops={'fontsize':14}, radius =0.75)
plt.axis('equal')
plt.legend()
plt.show()
# 중분류 추가해서 나타내보기 or 브랜드 축해서
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-3779499d3528> in <module>()
#       9 plt.show()
#      10 # 중분류 추가해서 나타내보기 or 브랜드 축해서
# ---> 11 group_names = df_e.index
#      12 group_sizes = df_e.values
#      13 group_explodes = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)
#
# NameError: name 'df_e' is not defined

# %%
res1 = df_c.groupby('Category').count()
res2 = df_c.groupby('sub_Category').count
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-b171f201ee1d> in <module>()
#       1 res1 = df_c.groupby('Category').count()
# ----> 2 res2 = df_c.groupby('sub_Category').count
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7639             squeeze=squeeze,  # type: ignore[arg-type]
#    7640             observed=observed,
# -> 7641             dropna=dropna,
#    7642         )
#    7643
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     895                 observed=observed,
#     896                 mutated=self.mutated,
# --> 897                 dropna=self.dropna,
# ...

# %%
fig = plt.figure(figsize = (10, 10))
plt.pie(res1[0], radius = 1)
plt.pie(res2[0], radius = 0.75)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-08c2167c8d49> in <module>()
#       1 fig = plt.figure(figsize = (10, 10))
#       2 plt.pie(res1[0], radius = 1)
# ----> 3 plt.pie(res2[0], radius = 0.75)
#       4 plt.show()
#       5
#
# NameError: name 'res2' is not defined

# %%
df_d = df_a.groupby('sub_Category').size().sort_values(ascending=False)
df_d


df_e = df_d[:19]
df_e
# Out:
# sub_Category
# 데님 팬츠         90
# 맨투맨/스웨트셔츠     84
# 후드 티셔츠        69
# 캔버스/단화        66
# 트레이닝/조거 팬츠    62
# 니트/스웨터        42
# 슈트 팬츠/슬랙스     35
# 셔츠/블라우스       34
# 카디건           34
# 러닝화/피트니스화     29
# 레더/라이더스 재킷    29
# 슈트/블레이저 재킷    28
# 캡/야구 모자       25
# 후드 집업         24
# 반팔 티셔츠        23
# 블루종/MA-1      23
# 백팩            21
# 메신저/크로스 백     20
# 구두            17
# dtype: int64

# %%
group_names = df_e.index
group_sizes = df_e.values
group_explodes = (0.05, 0.05, 0.05, 0.05, 0.05, 0.05, 0.05)

fig = plt.figure(figsize = (10, 10))
plt.pie(group_sizes, labels=group_names, autopct='%1.2f%%', startangle=90, textprops={'fontsize':14}, radius =0.75)
plt.axis('equal')
plt.legend()
plt.show()
# 중분류 추가해서 나타내보기 or 브랜드 축해서

# %%
df_sub = pd.DataFrame(df_d)

# %%
df_sub
# Out:
#                0
# sub_Category
# 데님 팬츠         90
# 맨투맨/스웨트셔츠     84
# 후드 티셔츠        69
# 캔버스/단화        66
# 트레이닝/조거 팬츠    62
# ...           ..
# 크로스백           1
# 쿼츠 아날로그        1
# 뷰티 디바이스        1
# 비니             1
# 샌들             1
#
# [67 rows x 1 columns]

# %%
df_d
# Out:
# sub_Category
# 데님 팬츠         90
# 맨투맨/스웨트셔츠     84
# 후드 티셔츠        69
# 캔버스/단화        66
# 트레이닝/조거 팬츠    62
#               ..
# 크로스백           1
# 쿼츠 아날로그        1
# 뷰티 디바이스        1
# 비니             1
# 샌들             1
# Length: 67, dtype: int64
